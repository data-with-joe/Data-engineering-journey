# %% [markdown]
# create external location in databricks
# create catalog formular1_incr
# create schemas
# create volume files in landing schema

# %%
#unity catalog. object names
catalog_name = 'formular1_incr'
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema = 'gold'

# %%
landing_folder_path = '/Volumes/formular1_incr/landing/files'
