# %%
{
  "name": "api crypto job",
  "email_notifications": {
    "no_alert_for_skipped_runs": false
  },
  "webhook_notifications": {},
  "timeout_seconds": 0,
  "schedule": {
    "quartz_cron_expression": "28 9 8 * * ?",
    "timezone_id": "Africa/Lagos",
    "pause_status": "UNPAUSED"
  },
  "max_concurrent_runs": 1,
  "tasks": [
    {
      "task_key": "01_api_ingestion",
      "run_if": "ALL_SUCCESS",
      "notebook_task": {
        "notebook_path": "01_api_ingestion",
        "source": "GIT"
      },
      "timeout_seconds": 0,
      "email_notifications": {},
      "webhook_notifications": {},
      "environment_key": "Default",
      "disabled": false
    },
    {
      "task_key": "02_silver_transform",
      "depends_on": [
        {
          "task_key": "01_api_ingestion"
        }
      ],
      "run_if": "ALL_SUCCESS",
      "notebook_task": {
        "notebook_path": "02_silver_transform",
        "source": "GIT"
      },
      "timeout_seconds": 0,
      "email_notifications": {},
      "webhook_notifications": {},
      "environment_key": "Default",
      "disabled": false
    },
    {
      "task_key": "03_gold_aggregations",
      "depends_on": [
        {
          "task_key": "02_silver_transform"
        }
      ],
      "run_if": "ALL_SUCCESS",
      "notebook_task": {
        "notebook_path": "03_gold_aggregations",
        "source": "GIT"
      },
      "timeout_seconds": 0,
      "email_notifications": {},
      "environment_key": "Default",
      "disabled": false
    }
  ],
  "git_source": {
    "git_url": "https://github.com/spec-gaming/Data-engineering-journey",
    "git_provider": "gitHub",
    "git_branch": "azure-databricks-fintech"
  },
  "queue": {
    "enabled": true
  },
  "environments": [
    {
      "environment_key": "Default",
      "spec": {
        "environment_version": "5"
      }
    }
  ],
  "performance_target": "PERFORMANCE_OPTIMIZED"
}
