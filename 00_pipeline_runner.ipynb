# %%
# %run /Workspace/Users/aladejoseph656@gmail.com/databricks-banking/01_bronze_ingestion/01_bronze_ingestion

# %% [markdown]
# #SILVER

# %%
# %run /Workspace/Users/aladejoseph656@gmail.com/databricks-banking/02_silver_transform/silver_accounts_transform

# %%
# %run /Workspace/Users/aladejoseph656@gmail.com/databricks-banking/02_silver_transform/silver_cards_transform

# %%
# %run /Workspace/Users/aladejoseph656@gmail.com/databricks-banking/02_silver_transform/silver_client_transform

# %%
# %run /Workspace/Users/aladejoseph656@gmail.com/databricks-banking/02_silver_transform/silver_disp_transform

# %%
# %run /Workspace/Users/aladejoseph656@gmail.com/databricks-banking/02_silver_transform/silver_district_transform

# %%
# %run /Workspace/Users/aladejoseph656@gmail.com/databricks-banking/02_silver_transform/silver_loans_transform

# %%
# %run /Workspace/Users/aladejoseph656@gmail.com/databricks-banking/02_silver_transform/silver_orders_transform

# %%
# %run /Workspace/Users/aladejoseph656@gmail.com/databricks-banking/02_silver_transform/silver_trans_transform

# %% [markdown]
# #GOLD

# %%
# %run ./03_gold/dim_accounts

# %%
# %run ./03_gold/dim_cards

# %%
# %run ./03_gold/dim_clients

# %%
# %run ./03_gold/dim_districts

# %%
# %run ./03_gold/dim_loans

# %%
# %run ./03_gold/fact_orders

# %%
# %run ./03_gold/fact_transaction
