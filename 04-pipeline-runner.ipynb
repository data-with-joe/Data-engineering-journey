# %%
print("Starting Fintech Exchange Rate Pipeline")
print("=" * 50)
print("\n[1/3] Running Bronze ingestion...")

# %%
# %run "./01_api_ingestion"

# %%
# %run "./02_silver_transform"

# %%
# %run "./03_gold_aggregations"

# %%
print("=" * 50)
print("Pipeline completed successfully")
